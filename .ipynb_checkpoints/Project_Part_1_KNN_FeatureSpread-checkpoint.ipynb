# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
breast_cancer_data = pd.read_csv('data.txt', header=None)

# %%
breast_cancer_data.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9    ...        22     23      24      25      26      27      28  \
# 0  0.14710   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %%
diagnostic_labels = breast_cancer_data.iloc[:,1]

# %%
diagnostic_labels.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
map_label = {'M':1,'B':0}

# %%
type(diagnostic_labels)
# Out:
# pandas.core.series.Series

# %%
labels = diagnostic_labels.map(map_label)

# %%
labels.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#drop id, diagnostic cols
#retain feature cols only
breast_cancer_data = breast_cancer_data.iloc[:,2:]

# %%
breast_cancer_data = breast_cancer_data.reset_index(drop=True)

# %%
len(breast_cancer_data.columns)
# Out:
# 30

# %%
#reindex cols to start from zero (for iteration)
breast_cancer_data.columns = [a for a in range(len(breast_cancer_data.columns))]

# %%
breast_cancer_data.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9    ...        20     21      22      23      24      25      26  \
# 0  0.07871   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.05667   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.05999   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.09744   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.05883   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        27      28       29
# 0  0.2654  0.4601  0.11890
# ...

# %%
data_stats = breast_cancer_data.describe()

# %%
data_stats
# Out:
#                0           1           2            3           4   \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                5           6           7           8           9      ...      \
# count  569.000000  569.000000  569.000000  569.000000  569.000000     ...
# mean     0.104341    0.088799    0.048919    0.181162    0.062798     ...
# std      0.052813    0.079720    0.038803    0.027414    0.007060     ...
# ...

# %%
feature_names = np.array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
       'mean smoothness', 'mean compactness', 'mean concavity',
       'mean concave points', 'mean symmetry', 'mean fractal dimension',
       'radius error', 'texture error', 'perimeter error', 'area error',
       'smoothness error', 'compactness error', 'concavity error',
       'concave points error', 'symmetry error',
       'fractal dimension error', 'worst radius', 'worst texture',
       'worst perimeter', 'worst area', 'worst smoothness',
       'worst compactness', 'worst concavity', 'worst concave points',
       'worst symmetry', 'worst fractal dimension'])

# %%
feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
feature_names[0]
# Out:
# 'mean radius'

# %%
data_benign = breast_cancer_data[labels==0]

# %%
data_benign.head()
# Out:
#         0      1      2      3        4        5        6         7       8   \
# 19  13.540  14.36  87.46  566.3  0.09779  0.08129  0.06664  0.047810  0.1885
# 20  13.080  15.71  85.63  520.0  0.10750  0.12700  0.04568  0.031100  0.1967
# 21   9.504  12.44  60.34  273.9  0.10240  0.06492  0.02956  0.020760  0.1815
# 37  13.030  18.42  82.61  523.8  0.08983  0.03766  0.02562  0.029230  0.1467
# 46   8.196  16.84  51.71  201.9  0.08600  0.05943  0.01588  0.005917  0.1769
#
#          9    ...         20     21     22     23       24       25       26  \
# 19  0.05766   ...     15.110  19.26  99.70  711.2  0.14400  0.17730  0.23900
# 20  0.06811   ...     14.500  20.49  96.09  630.5  0.13120  0.27760  0.18900
# 21  0.06905   ...     10.230  15.66  65.13  314.9  0.13240  0.11480  0.08867
# 37  0.05863   ...     13.300  22.81  84.46  545.9  0.09701  0.04619  0.04833
# 46  0.06503   ...      8.964  21.96  57.26  242.2  0.12970  0.13570  0.06880
#
#          27      28       29
# ...

# %%
data_malignant = breast_cancer_data[labels==1]

# %%
len(data_malignant)
# Out:
# 212

# %%
benign_stats = data_benign.describe()

# %%
benign_stats
# Out:
#                0           1           2           3           4           5   \
# count  357.000000  357.000000  357.000000  357.000000  357.000000  357.000000
# mean    12.146524   17.914762   78.075406  462.790196    0.092478    0.080085
# std      1.780512    3.995125   11.807438  134.287118    0.013446    0.033750
# min      6.981000    9.710000   43.790000  143.500000    0.052630    0.019380
# 25%     11.080000   15.150000   70.870000  378.200000    0.083060    0.055620
# 50%     12.200000   17.390000   78.180000  458.400000    0.090760    0.075290
# 75%     13.370000   19.760000   86.100000  551.100000    0.100700    0.097550
# max     17.850000   33.810000  114.600000  992.100000    0.163400    0.223900
#
#                6           7           8           9      ...              20  \
# count  357.000000  357.000000  357.000000  357.000000     ...      357.000000
# mean     0.046058    0.025717    0.174186    0.062867     ...       13.379801
# ...

# %%
malignant_stats = data_malignant.describe()

# %%
malignant_stats
# Out:
#                0           1           2            3           4   \
# count  212.000000  212.000000  212.000000   212.000000  212.000000
# mean    17.462830   21.604906  115.365377   978.376415    0.102898
# std      3.203971    3.779470   21.854653   367.937978    0.012608
# min     10.950000   10.380000   71.900000   361.600000    0.073710
# 25%     15.075000   19.327500   98.745000   705.300000    0.094010
# 50%     17.325000   21.460000  114.200000   932.000000    0.102200
# 75%     19.590000   23.765000  129.925000  1203.750000    0.110925
# max     28.110000   39.280000  188.500000  2501.000000    0.144700
#
#                5           6           7           8           9      ...      \
# count  212.000000  212.000000  212.000000  212.000000  212.000000     ...
# mean     0.145188    0.160775    0.087990    0.192909    0.062680     ...
# std      0.053987    0.075019    0.034374    0.027638    0.007573     ...
# ...

# %%
malignant_stats.loc['mean',0]
# Out:
# 17.46283018867925

# %%
import matplotlib.pylab as plt

# %%
from scipy import stats

# %%
data_benign[0]
# Out:
# 19     13.540
# 20     13.080
# 21      9.504
# 37     13.030
# 46      8.196
# 48     12.050
# 49     13.490
# 50     11.760
# 51     13.640
# 52     11.940
# 55     11.520
# 58     13.050
# 59      8.618
# 60     10.170
# 61      8.598
# 63      9.173
# 66      9.465
# 67     11.310
# 68      9.029
# 69     12.780
# 71      8.888
# 74     12.310
# 76     13.530
# 79     12.860
# 80     11.450
# 81     13.340
# 84     12.000
# 88     12.360
# 89     14.640
# 90     14.620
#         ...
# 530    11.750
# 531    11.670
# 532    13.680
# 534    10.960
# 537    11.690
# 538     7.729
# 539     7.691
# 540    11.540
# 541    14.470
# 542    14.740
# 543    13.210
# 544    13.870
# 545    13.620
# 546    10.320
# 547    10.260
# 548     9.683
# 549    10.820
# 550    10.860
# 551    11.130
# 552    12.770
# 553     9.333
# 554    12.880
# 555    10.290
# 556    10.160
# 557     9.423
# 558    14.590
# 559    11.510
# 560    14.050
# 561    11.200
# 568     7.760
# ...

# %%
benign_stats.loc['mean',0]
# Out:
# 12.14652380952381

# %%
np.linspace(benign_stats.loc['min',0],benign_stats.loc['max',0])
# Out:
# array([ 6.981     ,  7.20281633,  7.42463265,  7.64644898,  7.86826531,
#         8.09008163,  8.31189796,  8.53371429,  8.75553061,  8.97734694,
#         9.19916327,  9.42097959,  9.64279592,  9.86461224, 10.08642857,
#        10.3082449 , 10.53006122, 10.75187755, 10.97369388, 11.1955102 ,
#        11.41732653, 11.63914286, 11.86095918, 12.08277551, 12.30459184,
#        12.52640816, 12.74822449, 12.97004082, 13.19185714, 13.41367347,
#        13.6354898 , 13.85730612, 14.07912245, 14.30093878, 14.5227551 ,
#        14.74457143, 14.96638776, 15.18820408, 15.41002041, 15.63183673,
#        15.85365306, 16.07546939, 16.29728571, 16.51910204, 16.74091837,
#        16.96273469, 17.18455102, 17.40636735, 17.62818367, 17.85      ])

# %%
for p in range(30):
    x_b = np.linspace(benign_stats.loc['min',p],benign_stats.loc['max',p])
    plt.plot(x_b,stats.norm.pdf(x=x_b,loc=benign_stats.loc['mean',p],scale=benign_stats.loc['std',p]))
    
    x_m = np.linspace(malignant_stats.loc['min',p],malignant_stats.loc['max',p])
    plt.plot(x_m,stats.norm.pdf(x=x_m,loc=malignant_stats.loc['mean',p],scale=malignant_stats.loc['std',p]))

#     plt.plot(data_benign[p],stats.norm.pdf(x=data_benign[p],loc=benign_stats.loc['mean',p],scale=benign_stats.loc['std',p]))

#     plt.plot(data_malignant[p],stats.norm.pdf(x=data_malignant[p],loc=malignant_stats.loc['mean',p],scale=malignant_stats.loc['std',p]))
    plt.title('Feature ('+str(p)+')'+': '+feature_names[p])
    plt.show()

# %%
from sklearn.datasets import load_breast_cancer
dataset = load_breast_cancer(return_X_y=True)

# %%
pd.isna(dataset[0]).any()
# Out:
# False

# %%
pd.isna(dataset[1]).any()
# Out:
# False

# %%
dataset.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-3ded4c85834d> in <module>()
# ----> 1 dataset.describe()
#
# AttributeError: 'tuple' object has no attribute 'describe'

# %%
d = load_breast_cancer()

# %%
d.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict

# %%
breast_cancer_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aef282169e1f> in <module>()
# ----> 1 breast_cancer_data
#
# NameError: name 'breast_cancer_data' is not defined

# %%
X,y = dataset[0],dataset[1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
len(X_train) == len(y_train)
# Out:
# True

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # KNN Classifier...choosing best N

# %%
best_score = 0
best_k = 0
for i in range(1,25):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    knn_score = knn.score(X_test,y_test)
    if knn_score > best_score:
        best_score = knn_score
        best_k = i

# %%
best_score
# Out:
# 0.9787234042553191

# %%
best_k
# Out:
# 10

# %% [markdown]
# ## Cross-validate

# %% [markdown]
# ### Small dataset can handle multi-fold-cross validation

# %%
best_cv_score = 0
best_cv_k = 0
model = None 
for k in range(1,25):
    knn_cv = KNeighborsClassifier(n_neighbors=k)
    scores_cv = cross_val_score(knn_cv, X_train, y_train, scoring='accuracy',cv=10)
    mean_scores_cv = scores_cv.mean()*100
    
    print('Mean accuracy with 10-fold cross-validation is %s' % round(mean_scores_cv,2),' k=',k)

    if mean_scores_cv > best_cv_score:
        best_cv_score = mean_scores_cv
        best_cv_k = k
        model = knn_cv
# Out:
# Mean accuracy with 10-fold cross-validation is 89.47  k= 1
# Mean accuracy with 10-fold cross-validation is 88.68  k= 2
# Mean accuracy with 10-fold cross-validation is 90.24  k= 3
# Mean accuracy with 10-fold cross-validation is 89.7  k= 4
# Mean accuracy with 10-fold cross-validation is 90.77  k= 5
# Mean accuracy with 10-fold cross-validation is 91.3  k= 6
# Mean accuracy with 10-fold cross-validation is 90.77  k= 7
# Mean accuracy with 10-fold cross-validation is 91.3  k= 8
# Mean accuracy with 10-fold cross-validation is 90.26  k= 9
# Mean accuracy with 10-fold cross-validation is 90.51  k= 10
# Mean accuracy with 10-fold cross-validation is 90.8  k= 11
# Mean accuracy with 10-fold cross-validation is 91.84  k= 12
# Mean accuracy with 10-fold cross-validation is 91.04  k= 13
# Mean accuracy with 10-fold cross-validation is 90.51  k= 14
# Mean accuracy with 10-fold cross-validation is 90.5  k= 15
# Mean accuracy with 10-fold cross-validation is 90.23  k= 16
# ...

# %%
best_cv_score
# Out:
# 91.84374658058869

# %%
best_cv_k
# Out:
# 12

# %%
model
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#            weights='uniform')

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#            weights='uniform')

# %%
knn_accuracy = model.score(X_test,y_test)

# %%
knn_accuracy
# Out:
# 0.973404255319149
